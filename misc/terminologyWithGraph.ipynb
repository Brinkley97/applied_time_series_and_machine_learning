# %% [markdown]
# # Breakdown of Terminology w/ a Chart

# %%
import numpy as np
import pandas as pd
import matplotlib as plt

# %%
def random_plots(data, time_axis, measurements_axis, title):
    plot_ts = pd.DataFrame(data, columns=["Observations (Z)"])
    # print(plot_ts.columns)
    ax = plot_ts.plot(style='.-')
    ax.set(title=title, xlabel=time_axis, ylabel=measurements_axis)
    return plot_ts

# %%
def get_time():
    time_frame = pd.date_range(start='6/1/2022', end='6/30/2022')
    # print(type(time_frame))
    
    days_in_time_frame = time_frame.max() - time_frame.min() 
    # print(type(days_in_time_frame))
    
    convert_days_in_tf = days_in_time_frame.days + 1
    # print(type(convert_days_in_tf), convert_days_in_tf)
    
    return convert_days_in_tf

# %%
time = get_time()
data = np.random.randn(time)
x_axis = 'Time (days)'
y_axis = 'Numerical Measurements'
title = 'Time Series for XXX Phenomenon'
time_series_data = random_plots(data, x_axis, y_axis, title)

# %%
# print(type(time_series_data))
def create_df(ts_data):
    ts_data = pd.DataFrame(time_series_data)
    return ts_data

# %%
create_df(time_series_data)
# Out:
#     Observations (Z)
# 0           0.470155
# 1          -0.050952
# 2           0.617273
# 3          -0.976920
# 4          -1.790681
# 5          -2.255317
# 6          -1.816415
# 7           1.658985
# 8          -0.223981
# 9          -0.592524
# 10         -0.147912
# 11         -2.341104
# 12          1.413267
# 13         -0.163866
# 14          1.040190
# 15          1.136070
# 16         -0.549685
# 17         -1.932175
# 18          0.194326
# 19          1.195390
# 20          1.067786
# 21          0.487047
# 22         -0.994295
# 23          1.310679
# 24          0.132781
# 25          0.900625
# 26         -0.145718
# 27          1.285518
# 28         -0.229588
# 29          1.016056
