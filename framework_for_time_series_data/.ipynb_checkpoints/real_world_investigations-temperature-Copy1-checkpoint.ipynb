# %% [markdown]
# # On Analyzing Real World Time Series for Forecasting: Sunspots Data
# - NOTES: [real_world_investigations-base.ipynb](https://github.com/Brinkley97/applied_time_series_and_machine_learning/blob/main/framework_for_time_series_data/real_world_investigations-base.ipynb) by Detravious
#
# - TUTORIAL: [Autoregression Models for Time Series Forecasting With Python](https://machinelearningmastery.com/autoregression-models-time-series-forecasting-python/) by Jason Brownlee

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from collections import namedtuple
from data_loader import build_sunspots_uts
from ts_models import Model, AR, PersistenceWalkForward, MA, EvaluationMetric
from time_series import TimeSeriesFactory, UnivariateTimeSeries

# %% [markdown]
# ## Daily Minimum Temperate Data Pipeline
#
# 1. Load Raw Data
# 2. Plot Raw Data
# 3. Get Descriptive Statistics (ie: mean, median, range, etc)
# 4. Check Stationarity of Raw Data
# 5. Plot Autocorrelation and Partial Autocorrelation
# 6. Split Data
# 7. Initialize Autoregressive AR(p) Model
# 8. Predict Forecasts
# 9. Plot Actual Forecasts vs Predicted Forecasts
# 10. Initialize Persistence Random Walk Model
# 11. Predict Forecasts on Raw Data for Persistence Random Walk Model
# 12. Follow-up

# %% [markdown]
# ### Load Raw Data

# %%
sunspots = build_sunspots_uts()
sunspots
# Out:
# ::
#
#     Number of Observations - 309 (Annual 1700 - 2008)
#     Number of Variables - 1
#     Variable name definitions::
#
#         SUNACTIVITY - Number of sunspots for each year
#
#     The data file contains a 'YEAR' variable that is not returned by load.
# UnivariateTimeSeries(SUNACTIVITY)

# %%
sunspots_df = sunpots.get_as_df()
sunspots_df
# Out:
#         SUNACTIVITY
# YEAR
# 1700.0          5.0
# 1701.0         11.0
# 1702.0         16.0
# 1703.0         23.0
# 1704.0         36.0
# ...             ...
# 2004.0         40.4
# 2005.0         29.8
# 2006.0         15.2
# 2007.0          7.5
# 2008.0          2.9
#
# [309 rows x 1 columns]

# %% [markdown]
# ### Plot Raw Data

# %%
sunspots.plot(tick_skip=50)

# %% [markdown]
# ### Get Descriptive Statistics

# %%
sunspots.get_statistics()
# Out:
#        SUNACTIVITY
# count   309.000000
# mean     49.752104
# std      40.452595
# min       0.000000
# 25%      16.000000
# 50%      40.000000
# 75%      69.800000
# max     190.200000

# %%
sunspots.max_min_range()
# Out:
# {'Max': SUNACTIVITY    190.2
#  dtype: float64,
#  'Min': SUNACTIVITY    0.0
#  dtype: float64,
#  'Range': SUNACTIVITY    190.2
#  dtype: float64}

# %% [markdown]
# ### Check Stationarity of Raw Data

# %%
sunspots.stationarity_test(sunspots_df)
# Out:
# Series is non-stationary as 0.05307642172812057 > 0.05

# %% [markdown]
# ### Plot Autocorrelation and Partial Autocorrelation
# - How the relationship between observations and its historical data changes over time.
# - In this case, we have a positive high autocorrelation meaning that we have some relationships between the 1st observation and the k-th observation (at that lag).
# - Look for which points fall outside of blue region.

# %%
sunspots.plot_autocorrelation(40)

# %%
sunspots.plot_partial_autocorrelation(40)

# %% [markdown]
# ### Get Returns Data

# %%
sunspots_returns = sunspots_df[sunspots_df["SUNACTIVITY"]].pct_change().dropna().values.copy()
sunspots_returns
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 sunspots_returns = sunspots_df[sunspots_df["SUNACTIVITY"]].pct_change().dropna().values.copy()
#       2 sunspots_returns
#
# File ~/opt/anaconda3/envs/time_series/lib/python3.9/site-packages/pandas/core/frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File ~/opt/anaconda3/envs/time_series/lib/python3.9/site-packages/pandas/core/indexes/base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
#    6068     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6070 self._raise_if_missing(keyarr, indexer, axis_name)
#    6072 keyarr = self.take(indexer)
#    6073 if isinstance(key, Index):
#    6074     # GH 42790 - Preserve name from an Index
#
# File ~/opt/anaconda3/envs/time_series/lib/python3.9/site-packages/pandas/core/indexes/base.py:6130, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6128     if use_interval_msg:
#    6129         key = list(key)
# -> 6130     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6132 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6133 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Float64Index([  5.0,  11.0,  16.0,  23.0,  36.0,  58.0,  29.0,  20.0,  10.0,\n                8.0,\n              ...\n               93.3, 119.6, 111.0, 104.0,  63.7,  40.4,  29.8,  15.2,   7.5,\n                2.9],\n             dtype='float64', length=309)] are in the [columns]"

# %%
sunspots_returns_df = sunspots.get_as_df()
sunspots_returns_df
# Out:
#         SUNACTIVITY
# YEAR
# 1700.0          5.0
# 1701.0         11.0
# 1702.0         16.0
# 1703.0         23.0
# 1704.0         36.0
# ...             ...
# 2004.0         40.4
# 2005.0         29.8
# 2006.0         15.2
# 2007.0          7.5
# 2008.0          2.9
#
# [309 rows x 1 columns]

# %%
sunspots_returns.plot(tick_skip=25)

# %%
sunspots_returns.plot_autocorrelation()
# Out:
# /Users/brinkley97/Documents/development/applied_time_series_and_machine_learning/framework_for_time_series_data/time_series.py:349: RuntimeWarning: invalid value encountered in divide
#   return autocovariance_matrix / self.variance()[0]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 sunspots_returns.plot_autocorrelation()
#
# File ~/Documents/development/applied_time_series_and_machine_learning/framework_for_time_series_data/time_series.py:439, in UnivariateTimeSeries.plot_autocorrelation(self, max_lag, plot_full)
#     437 # Make the plot y bounds go from -1 to 1
#     438 PADDING = .1
# --> 439 plt.ylim(np.min(y_axis_data) - PADDING, np.max(y_axis_data) + PADDING)
#     441 plt.show()
#     443 tsaplots.plot_acf(self.data)
#
# File ~/opt/anaconda3/envs/time_series/lib/python3.9/site-packages/matplotlib/pyplot.py:1770, in ylim(*args, **kwargs)
#    1768 if not args and not kwargs:
#    1769     return ax.get_ylim()
# -> 1770 ret = ax.set_ylim(*args, **kwargs)
#    1771 return ret
#
# File ~/opt/anaconda3/envs/time_series/lib/python3.9/site-packages/matplotlib/_api/deprecation.py:454, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     448 if len(args) > name_idx:
#     449     warn_deprecated(
#     450         since, message="Passing the %(name)s %(obj_type)s "
#     451         "positionally is deprecated since Matplotlib %(since)s; the "
#     452         "parameter will become keyword-only %(removal)s.",
#     453         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 454 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/time_series/lib/python3.9/site-packages/matplotlib/axes/_base.py:3918, in _AxesBase.set_ylim(self, bottom, top, emit, auto, ymin, ymax)
#    3916         raise TypeError("Cannot pass both 'top' and 'ymax'")
#    3917     top = ymax
# -> 3918 return self.yaxis._set_lim(bottom, top, emit=emit, auto=auto)
#
# File ~/opt/anaconda3/envs/time_series/lib/python3.9/site-packages/matplotlib/axis.py:1112, in Axis._set_lim(self, v0, v1, emit, auto)
#    1108 name, = [name for name, axis in self.axes._axis_map.items()
#    1109          if axis is self]  # The axis name.
#    1111 self.axes._process_unit_info([(name, (v0, v1))], convert=False)
# -> 1112 v0 = self.axes._validate_converted_limits(v0, self.convert_units)
#    1113 v1 = self.axes._validate_converted_limits(v1, self.convert_units)
#    1115 if v0 is None or v1 is None:
#    1116     # Axes init calls set_xlim(0, 1) before get_xlim() can be called,
#    1117     # so only grab the limits if we really need them.
#
# File ~/opt/anaconda3/envs/time_series/lib/python3.9/site-packages/matplotlib/axes/_base.py:3606, in _AxesBase._validate_converted_limits(self, limit, convert)
#    3603 converted_limit = convert(limit)
#    3604 if (isinstance(converted_limit, Real)
#    3605         and not np.isfinite(converted_limit)):
# -> 3606     raise ValueError("Axis limits cannot be NaN or Inf")
#    3607 return converted_limit
#
# ValueError: Axis limits cannot be NaN or Inf

# %%
sunspots_returns.plot_partial_autocorrelation(35)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 sunspots_returns.plot_partial_autocorrelation(35)
#
# File ~/Documents/development/applied_time_series_and_machine_learning/framework_for_time_series_data/time_series.py:448, in UnivariateTimeSeries.plot_partial_autocorrelation(self, max_lag)
#     446 def plot_partial_autocorrelation(self, max_lag: int = 1):
# --> 448     tsaplots.plot_pacf(self.data.squeeze(), lags=max_lag, method='ywm')
#     449     plt.show()
#
# File ~/opt/anaconda3/envs/time_series/lib/python3.9/site-packages/statsmodels/graphics/tsaplots.py:363, in plot_pacf(x, ax, lags, alpha, method, use_vlines, title, zero, vlines_kwargs, **kwargs)
#     361     acf_x = pacf(x, nlags=nlags, alpha=alpha, method=method)
#     362 else:
# --> 363     acf_x, confint = pacf(x, nlags=nlags, alpha=alpha, method=method)
#     365 _plot_corr(
#     366     ax,
#     367     title,
#    (...)
#     374     **kwargs,
#     375 )
#     377 return fig
#
# File ~/opt/anaconda3/envs/time_series/lib/python3.9/site-packages/statsmodels/tsa/stattools.py:1009, in pacf(x, nlags, method, alpha)
#    1007     ret = pacf_yw(x, nlags=nlags, method="adjusted")
#    1008 elif method in ("ywm", "ywmle", "yw_mle"):
# -> 1009     ret = pacf_yw(x, nlags=nlags, method="mle")
#    1010 elif method in ("ld", "lda", "ldadjusted", "ld_adjusted"):
#    1011     acv = acovf(x, adjusted=True, fft=False)
#
# File ~/opt/anaconda3/envs/time_series/lib/python3.9/site-packages/statsmodels/tsa/stattools.py:746, in pacf_yw(x, nlags, method)
#     744 pacf = [1.0]
#     745 for k in range(1, nlags + 1):
# --> 746     pacf.append(yule_walker(x, k, method=method)[0][-1])
#     747 return np.array(pacf)
#
# File ~/opt/anaconda3/envs/time_series/lib/python3.9/site-packages/statsmodels/regression/linear_model.py:1467, in yule_walker(x, order, method, df, inv, demean)
#    1464     r[k] = (x[0:-k] * x[k:]).sum() / (n - k * adj_needed)
#    1465 R = toeplitz(r[:-1])
# -> 1467 rho = np.linalg.solve(R, r[1:])
#    1468 sigmasq = r[0] - (r[1:]*rho).sum()
#    1469 sigma = np.sqrt(sigmasq) if not np.isnan(sigmasq) and sigmasq > 0 else np.nan
#
# File <__array_function__ internals>:180, in solve(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/time_series/lib/python3.9/site-packages/numpy/linalg/linalg.py:400, in solve(a, b)
#     398 signature = 'DD->D' if isComplexType(t) else 'dd->d'
#     399 extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 400 r = gufunc(a, b, signature=signature, extobj=extobj)
#     402 return wrap(r.astype(result_t, copy=False))
#
# File ~/opt/anaconda3/envs/time_series/lib/python3.9/site-packages/numpy/linalg/linalg.py:89, in _raise_linalgerror_singular(err, flag)
#      88 def _raise_linalgerror_singular(err, flag):
# ---> 89     raise LinAlgError("Singular matrix")
#
# LinAlgError: Singular matrix

# %% [markdown]
# ### Split Data
# - Splitting according to the TUTORIAL so we can forecast the last 7 days. Do this type of forecast to see how model is performing. If model performs how we need, then update notebook to forecast the next 7 days.

# %% [raw]
# train_2, test_2 = temperatures.get_series()[1:len(temperatures.get_series())-7], temperatures.get_series()[len(temperatures.get_series())-7:]

# %%
train, validation, test = sunspots.get_train_validation_test_split(0.95, 0.0)
# Out:
# 0 293
# 293 293
# 293 309

# %%
train.get_as_df()
# Out:
#         UnivariateTimeSeries(SUNACTIVITY)[0:293]
# YEAR
# 1700.0                                       5.0
# 1701.0                                      11.0
# 1702.0                                      16.0
# 1703.0                                      23.0
# 1704.0                                      36.0
# ...                                          ...
# 1988.0                                     100.2
# 1989.0                                     157.6
# 1990.0                                     142.6
# 1991.0                                     145.7
# 1992.0                                      94.3
#
# [293 rows x 1 columns]

# %%
validation.get_as_df()
# Out:
# Empty DataFrame
# Columns: [UnivariateTimeSeries(SUNACTIVITY)[293:293]]
# Index: []

# %%
test.get_as_df()
# Out:
#         UnivariateTimeSeries(SUNACTIVITY)[293:309]
# YEAR
# 1993.0                                        54.6
# 1994.0                                        29.9
# 1995.0                                        17.5
# 1996.0                                         8.6
# 1997.0                                        21.5
# 1998.0                                        64.3
# 1999.0                                        93.3
# 2000.0                                       119.6
# 2001.0                                       111.0
# 2002.0                                       104.0
# 2003.0                                        63.7
# 2004.0                                        40.4
# 2005.0                                        29.8
# 2006.0                                        15.2
# 2007.0                                         7.5
# 2008.0                                         2.9

# %%
expected_forecast = test.get_series()
expected_forecast

# %% [markdown]
# ### Initialize AR Model
# - How to determine the proper lag value? Look at the Partial ACor plot. Being that we're out of the blue area at lag 3, we'll set our lag to be 3. We'll also test for lag 31 which is the first negative lag that's outside of the blue. The TUTORIAL has lag 29, so we'll test that as well.
# - How to understand the model summary?

# %%
lags_to_test = [3, 31, 29]

# %%
ar_model_class = AR()

trained_ar_models = ar_model_class.train_ar_model(train.get_series(), lags_to_test)

# %%
trained_ar_models[0]

# %%
trained_ar_models[1]

# %%
len_historical_data, historical_data = train.get_historical_data()
len_historical_data, historical_data

# %%
len_historical_data

# %%
historical_data

# %% [markdown]
# ### Predict Forecasts on Raw Data for AR Model

# %%
predictions = ar_model_class.predict(trained_ar_models, len_historical_data, train, test)
predictions

# %%
mse_temperatures = EvaluationMetric.eval_mse(expected_forecast, predictions, per_element=True)
mse_temperatures

# %% [markdown]
# ### Plot Actual Forecasts vs Predicted Forecasts

# %%
EvaluationMetric.plot_forecast(expected_forecast, predictions, lags_to_test, with_lags=True)

# %% [markdown]
# ### Initialize Persistence Random Walk Model

# %%
temp_df

# %%
temp_values = temperatures.get_series()
temp_values

# %%
temp_lags_df = pd.concat([temp_df.shift(1), temp_df], axis=1)
temp_lags_df

# %%
temp_lags_df.columns = ['t - 1', 't + 1']
temp_lags_df

# %%
X = temp_lags_df.values
train, test = X[1:len(X)-7], X[len(X)-7:]
train_X, train_y = train[:,0], train[:,1]
test_X, test_y = test[:,0], test[:,1]

# %%
len(train), len(test), len(train_X), len(train_y), len(test_X), len(test_y)

# %%
prw_model = PersistenceWalkForward()
prw_model

# %% [markdown]
# ### Predict Forecasts on Raw Data for Persistence Random Walk Model

# %%
prw_predictions = prw_model.predict(test_X)
prw_predictions = np.array(prw_predictions)
prw_predictions

# %%
test_y

# %%
mse_temperatures = EvaluationMetric.eval_mse(test_y, prw_predictions, per_element=False)
mse_temperatures

# %%
lags_to_test = [0]
EvaluationMetric.plot_forecast(test_y, prw_predictions, lags_to_test, with_lags=False)

# %% [markdown]
# ### Initialize MA(q) Model
#
# - How to determine the proper error term? Look at the ACor plot. There's no real indication of what values to choose, so I'll randomly pick some.
# - How to understand the model summary?

# %%
train, validation, test = temperatures.get_train_validation_test_split(0.9983, 0.0)

# %%
errors_to_test = [3, 8, 17, 31, 29]

# %%
ma_model_class = MA()

trained_ma_models = ma_model_class.train_model(train.get_series(), errors_to_test)

# %%
ma_predictions = ma_model_class.predict(trained_ma_models, len_historical_data, train, test)
ma_predictions

# %%
expected_forecast = test.get_series()
expected_forecast

# %%
mse_temperatures = EvaluationMetric.eval_mse(expected_forecast, ma_predictions, per_element=True)
mse_temperatures

# %%
EvaluationMetric.plot_forecast(expected_forecast, ma_predictions, errors_to_test, with_lags=True)

# %% [markdown]
# ### Follow-up
# - What can we determine from this?
# - Which AR(p) lag performs the best?
# - Can we do better?
