# %% [markdown]
# # On Analyzing Real World Time Series for Forecasting Stock Data
# - Reference: real_world_investigation-base.ipynb

# %%
from collections import namedtuple
from data_loader import build_stock_uts
from ts_models import Model, AR, EvaluationMetric
from time_series import TimeSeriesFactory, UnivariateTimeSeries

# %% [markdown]
# ## Stock Data Analysis
#
# 1. Load Raw Data
# 2. Plot Raw Data
# 3. Get Descriptive Statistics (ie: mean, median, range, etc) of Raw Data
# 4. Check Stationarity of Raw Data
# 5. Plot Autocorrelation and Partial Autocorrelation of Raw Data
# 6. Get Returns Data
# 7. Plot Returns Data
# 8. Get Descriptive Statistics (ie: mean, median, range, etc) of Returns Data
# 9. Check Stationarity of Returns Data
# 10. Plot Autocorrelation and Partial Autocorrelation of Returns Data
# 11. Split Returns Data
# 12. Initialize Autoregressive AR(p) Model
# 13. Predict Forecasts for Returns Data
# 14. Plot Actual Forecasts vs Predicted Forecasts for Returns Data
# 15. Follow-up

# %% [markdown]
# ### Load Raw Data

# %%
# Only grab stocks whose data is available for the entire time period
start_date, end_date = "2013-01-01", "2023-10-08"
Stock = namedtuple("Stock", ["symbol", "name"])
stocks = [
    ("^GSPC", "S&P 500"),
    ("AAPL", "Apple"),
    ("INTC", "Intel"),
    ("AMZN", "Amazon"),
    ("TSLA", "Tesla"),
    ("GOOGL", "Google")
]
stocks = [Stock(*s) for s in stocks]
stocks = {s.symbol: build_stock_uts(s.symbol, s.name, start_date=start_date, end_date=end_date) for s in stocks}
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
values_cols = list(stocks.keys())
stock_mvts = TimeSeriesFactory.create_time_series(
    time_col="date",
    time_values=stocks[values_cols[0]].data.index,
    values_cols=values_cols,
    values=[stock.get_series() for stock in stocks.values()]
)

# %%
type(stocks['AAPL']), stocks['AAPL']
# Out:
# (time_series.UnivariateTimeSeries, UnivariateTimeSeries(Open))

# %% [markdown]
# How to call the created object
# - stocks['AAPL'] is our `object`
# - `object` `.method`
# - NOTE: Do NOT need `()` when calling methods with `@property`

# %%
aapl_series = stocks['AAPL'].get_series()
aapl_series
# Out:
# array([ 19.77928543,  19.56714249,  19.17749977, ..., 171.22000122,
#        172.25999451, 171.08999634])

# %%
aapl_df = stocks['AAPL'].get_as_df()
aapl_df
# Out:
#                   Open
# Date
# 2013-01-02   19.779285
# 2013-01-03   19.567142
# 2013-01-04   19.177500
# 2013-01-07   18.642857
# 2013-01-08   18.900356
# ...                ...
# 2023-09-28  169.339996
# 2023-09-29  172.020004
# 2023-10-02  171.220001
# 2023-10-03  172.259995
# 2023-10-04  171.089996
#
# [2708 rows x 1 columns]

# %% [markdown]
# ### Plot Raw Data

# %%
stocks['AAPL'].plot(tick_skip=250)

# %% [markdown]
# ### Get Descriptive Statistics of Raw Data

# %%
stocks['AAPL'].get_statistics()
# Out:
#               Open
# count  2708.000000
# mean     69.814046
# std      54.382953
# min      13.856071
# 25%      27.469999
# 50%      43.488750
# 75%     125.117502
# max     196.240005

# %%
stocks['AAPL'].max_min_range()
# Out:
# {'Max': Open    196.240005
#  dtype: float64,
#  'Min': Open    13.856071
#  dtype: float64,
#  'Range': Open    182.383934
#  dtype: float64}

# %% [markdown]
# ### Check Stationarity of Raw Data
#
# - With financial data, we expect it to be non-stationary.
#     - Can we verify this non-stationary with plotting the Autocorrelation?

# %%
stocks['AAPL'].stationarity_test(aapl_df)
# Out:
# Series is non-stationary as 0.9591124444129786 > 0.05

# %% [markdown]
# ### Plot Autocorrelation and Partial Autocorrelation of Raw Data
#
# - Below, there seems to be a high ACor, which means there's NOT such a difference between our 1st observation and k-th lag observation
#     - What to do with this?  We must take the `returns`.
# - The Partial ACor dies out after 2. Why?

# %%
stocks['AAPL'].plot_autocorrelation(35)

# %%
stocks['AAPL'].plot_partial_autocorrelation(35)

# %% [markdown]
# ### Get Returns Data
#
# - Forecast returns
# - Why: To have more stationarity compared to the prices `Open` which is non-stationary
# - Calculate with the `percent change` between $ z_{t-1} $ and $ z_t $
#     - If `percent change` < 0, then stock price is going down, hence a **loss** from $ z_{t-1} \rightarrow z_t $
#     - If `percent change` > 0, then stock price is going up, hence a **gain** from $ z_{t-1} \rightarrow z_t $
#     - If `percent change` = 0, then stock price is constant, hence a **no loss nor no gain** from $ z_{t-1} \rightarrow z_t $
# - NOTE: Shift the date by 1 because we don't have anything to subtract the 0th date by.

# %%
aapl_returns = stocks['AAPL'].data_augment_for_returns()
aapl_returns
# Out:
# UnivariateTimeSeries(Returns)

# %%
aapl_returns_df = aapl_returns.get_as_df()
aapl_returns_df
# Out:
#              Returns
# Date
# 2013-01-03 -0.010726
# 2013-01-04 -0.019913
# 2013-01-07 -0.027879
# 2013-01-08  0.013812
# 2013-01-09 -0.012679
# ...              ...
# 2023-09-28 -0.019001
# 2023-09-29  0.015826
# 2023-10-02 -0.004651
# 2023-10-03  0.006074
# 2023-10-04 -0.006792
#
# [2707 rows x 1 columns]

# %% [markdown]
# ### Plot Returns Data

# %%
aapl_returns.plot(tick_skip=250)

# %% [markdown]
# ### Get Descriptive Statistics of Returns Data

# %%
aapl_returns.get_statistics()
# Out:
#            Returns
# count  2707.000000
# mean      0.000969
# std       0.018533
# min      -0.140904
# 25%      -0.007898
# 50%       0.001423
# 75%       0.010269
# max       0.171182

# %% [markdown]
# ### Check Stationarity of Returns Data

# %%
aapl_returns.stationarity_test(aapl_returns_df)
# Out:
# Series is stationary as 0.0 < 0.05

# %% [markdown]
# ### Plot Autocorrelation and Partial Autocorrelation of Returns Data
#
# - Below, the ACor between our 1st observation and k-th lag observation is low. This ACor resembles the Raw Data Partial ACor plot. Why?
# - The Partial ACor is similar (to the Raw Data Partial ACor plo), except it here, it dies out at 2 (compared to the Raw Data Partial ACor plot which dies out after 2). Why?

# %%
aapl_returns.plot_autocorrelation(35)

# %%
aapl_returns.plot_partial_autocorrelation(35)

# %% [markdown]
# ### Split Returns Data
#
# - Splitting so we can forecast the last 7 days. Do this type of forecast to see how model is performing. If model performs how we need, then update notebook to forecast the next 7 days.

# %%
aapl_returns_len = len(aapl_returns_df)
aapl_returns_len
# Out:
# 2707

# %%
get_train_len = len(aapl_returns_df[:2700])
get_train_len
# Out:
# 2700

# %%
get_train_percentage = float(get_train_len / aapl_returns_len)
get_train_percentage
# Out:
# 0.9974141115626154

# %%
train, validation, test = aapl_returns.get_train_validation_test_split(get_train_percentage, 0.0)
# Out:
# 0 2700
# 2700 2700
# 2700 2707

# %%
train
# Out:
# UnivariateTimeSeries(UnivariateTimeSeries(Returns)[0:2700])

# %%
train.get_as_df()
# Out:
#             UnivariateTimeSeries(Returns)[0:2700]
# Date
# 2013-01-03                              -0.010726
# 2013-01-04                              -0.019913
# 2013-01-07                              -0.027879
# 2013-01-08                               0.013812
# 2013-01-09                              -0.012679
# ...                                           ...
# 2023-09-19                               0.005893
# 2023-09-20                               0.009802
# 2023-09-21                              -0.026275
# 2023-09-22                               0.000687
# 2023-09-25                              -0.002691
#
# [2700 rows x 1 columns]

# %%
validation
# Out:
# UnivariateTimeSeries(UnivariateTimeSeries(Returns)[2700:2700])

# %%
validation.get_as_df()
# Out:
# Empty DataFrame
# Columns: [UnivariateTimeSeries(Returns)[2700:2700]]
# Index: []

# %%
test
# Out:
# UnivariateTimeSeries(UnivariateTimeSeries(Returns)[2700:2707])

# %%
test.get_as_df()
# Out:
#             UnivariateTimeSeries(Returns)[2700:2707]
# Date
# 2023-09-26                                  0.003559
# 2023-09-27                                 -0.012584
# 2023-09-28                                 -0.019001
# 2023-09-29                                  0.015826
# 2023-10-02                                 -0.004651
# 2023-10-03                                  0.006074
# 2023-10-04                                 -0.006792

# %%
expected_forecast = test.get_series()
expected_forecast
# Out:
# array([ 0.00355919, -0.01258444, -0.01900127,  0.0158262 , -0.00465064,
#         0.00607402, -0.00679205])

# %% [markdown]
# ### Initialize Autoregressive AR(p) Model
#
# - How to determine the proper lag value? Look at the Partial ACor plot. Being that we're out of the blue area at lag 3, we'll set our lag to be 3.
#     - Why Partial ACor plot and not ACor plot?
#     - What if we take lags from ACor plot anyway? Say lags 5, 10, and 15 because they all have the most correlation (postive and negative) for their clusters, respectfully.
# - How to understand the model summary?

# %%
positive_pacor = [6, 12, 17]
negative_pacor = [2, 16, 22, 33]
lags_to_test = positive_pacor + negative_pacor
lags_to_test = sorted(lags_to_test)
lags_to_test
# Out:
# [2, 6, 12, 16, 17, 22, 33]

# %%
# create an object from the AR() class
ar_model_class = AR()

# call the function to train our AR model
trained_ar_models = ar_model_class.train_ar_model(train.get_series(), lags_to_test)
# Out:
# Model 1 with a lag of 2
# Model 2 with a lag of 6
# Model 3 with a lag of 12
# Model 4 with a lag of 16
# Model 5 with a lag of 17
# Model 6 with a lag of 22
# Model 7 with a lag of 33

# %%
len_historical_data, historical_data = train.get_historical_data()
len_historical_data
# Out:
# 2700

# %% [markdown]
# ### Predict Forecasts of Retruns Data

# %%
predictions = ar_model_class.ar_predict(trained_ar_models, len_historical_data, train, test)
predictions
# Out:
# Model 1 <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x13a6c26a0>
# Model 2 <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x13a65f9a0>
# Model 3 <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x13a677cd0>
# Model 4 <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x13a6d3f70>
# Model 5 <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x13a6a2820>
# Model 6 <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x13a636790>
# Model 7 <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x13a5f6730>
# [array([0.00131387, 0.00102124, 0.00098177, 0.00098993, 0.00098986,
#         0.00098974, 0.00098975]),
#  array([ 1.84858456e-03,  1.70552179e-03,  8.50551191e-04, -5.15001749e-05,
#          9.87763299e-04,  8.83153005e-04,  1.08004930e-03]),
#  array([0.00117543, 0.0014775 , 0.000993  , 0.0010241 , 0.0010948 ,
#         0.00051217, 0.0014332 ]),
#  array([-2.98631620e-03,  3.88709134e-03,  7.14874684e-05,  2.84722756e-03,
#         -1.18294330e-04, -2.13191092e-04,  2.24014514e-03]),
#  array([-2.74981253e-03,  4.14197681e-03, -9.47379189e-06,  2.73876950e-03,
#         -1.28182614e-03,  1.81136837e-04,  2.47036991e-03]),
#  array([-1.70946455e-03,  5.49773453e-03, -6.26162774e-05,  1.93430279e-03,
#         -2.59535936e-03, -3.16339447e-03,  1.86270627e-03]),
#  array([-0.00105848,  0.00471544, -0.00029095,  0.00157412, -0.00249429,
#         -0.00266052,  0.00055353])]

# %%
mse_gsts = EvaluationMetric.eval_mse(expected_forecast, predictions)
mse_gsts
# Out:
# expected [ 0.00355919 -0.01258444 -0.01900127  0.0158262  -0.00465064  0.00607402
#  -0.00679205] predicted [0.00131387 0.00102124 0.00098177 0.00098993 0.00098986 0.00098974
#  0.00098975] mse 0.011512813391002498
# expected [ 0.00355919 -0.01258444 -0.01900127  0.0158262  -0.00465064  0.00607402
#  -0.00679205] predicted [ 1.84858456e-03  1.70552179e-03  8.50551191e-04 -5.15001749e-05
#   9.87763299e-04  8.83153005e-04  1.08004930e-03] mse 0.011796075325069225
# expected [ 0.00355919 -0.01258444 -0.01900127  0.0158262  -0.00465064  0.00607402
#  -0.00679205] predicted [0.00117543 0.0014775  0.000993   0.0010241  0.0010948  0.00051217
#  0.0014332 ] mse 0.011673490779512637
# expected [ 0.00355919 -0.01258444 -0.01900127  0.0158262  -0.00465064  0.00607402
#  -0.00679205] predicted [-2.98631620e-03  3.88709134e-03  7.14874684e-05  2.84722756e-03
#  -1.18294330e-04 -2.13191092e-04  2.24014514e-03] mse 0.011880538062925503
# expected [ 0.00355919 -0.01258444 -0.01900127  0.0158262  -0.00465064  0.00607402
#  -0.00679205] predicted [-2.74981253e-03  4.14197681e-03 -9.47379189e-06  2.73876950e-03
#  -1.28182614e-03  1.81136837e-04  2.47036991e-03] mse 0.011852744476671822
# expected [ 0.00355919 -0.01258444 -0.01900127  0.0158262  -0.00465064  0.00607402
#  -0.00679205] predicted [-1.70946455e-03  5.49773453e-03 -6.26162774e-05  1.93430279e-03
#  -2.59535936e-03 -3.16339447e-03  1.86270627e-03] mse 0.012368391387289191
# expected [ 0.00355919 -0.01258444 -0.01900127  0.0158262  -0.00465064  0.00607402
#  -0.00679205] predicted [-0.00105848  0.00471544 -0.00029095  0.00157412 -0.00249429 -0.00266052
#   0.00055353] mse 0.012004201688596233

# %% [markdown]
# ### Plot Actual Forecasts vs Predicted Forecasts for Returns Data

# %%
EvaluationMetric.plot_forecast(expected_forecast, predictions, lags_to_test)

# %% [markdown]
# ### Follow-up
# - What can we determine from this?
#     - None of the models with the specified lag are performing well. Why?
# - Which AR(p) lag performs the best?
#     - Difficult to state.
# - Can we do better?
#     - We must lol!
