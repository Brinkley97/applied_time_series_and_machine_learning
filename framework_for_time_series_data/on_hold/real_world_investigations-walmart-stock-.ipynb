# %% [markdown]
# # On Analyzing Real World Time Series for Forecasting Stock Data
# - Reference: real_world_investigation-base.ipynb

# %%
from collections import namedtuple
from data_loader import build_stock_uts
from ts_models import Model, AR, PersistenceWalkForward, EvaluationMetric
from time_series import TimeSeriesFactory, UnivariateTimeSeries

# %% [markdown]
# ## Stock Data Analysis
#
# 1. Load Raw Data
# 2. Plot Raw Data
# 3. Get Descriptive Statistics (ie: mean, median, range, etc) of Raw Data
# 4. Check Stationarity of Raw Data
# 5. Plot Autocorrelation and Partial Autocorrelation of Raw Data
# 6. Get Returns Data
#     - Returns = log difference
# 7. Plot Returns Data
# 8. Get Descriptive Statistics (ie: mean, median, range, etc) of Returns Data
# 9. Check Stationarity of Returns Data
# 10. Plot Autocorrelation and Partial Autocorrelation of Returns Data
# 11. Split Returns Data
# 12. Initialize Autoregressive AR(p) Model
# 13. Predict Forecasts for Returns Data
# 14. Plot Actual Forecasts vs Predicted Forecasts for Returns Data
# 15. Initialize Persistence Random Walk Model
# 16. Predict Forecasts on Raw Data for Persistence Random Walk Model
# 17. Follow-up

# %% [markdown]
# ### Load Raw Data

# %%
# Only grab stocks whose data is available for the entire time period
start_date, end_date = "2013-01-01", "2023-10-16"
Stock = namedtuple("Stock", ["symbol", "name"])
stocks = [
    ("^GSPC", "S&P 500"),
    ("AAPL", "Apple"),
    ("WMT", "Walmart")
]
stocks = [Stock(*s) for s in stocks]
stocks = {s.symbol: build_stock_uts(s.symbol, s.name, start_date=start_date, end_date=end_date) for s in stocks}
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
values_cols = list(stocks.keys())
stock_mvts = TimeSeriesFactory.create_time_series(
    time_col="date",
    time_values=stocks[values_cols[0]].data.index,
    values_cols=values_cols,
    values=[stock.get_series() for stock in stocks.values()]
)

# %%
stock_symbol = 'WMT'
col = 'Close'
type(stocks[stock_symbol]), stocks[stock_symbol]
# Out:
# (time_series.UnivariateTimeSeries, UnivariateTimeSeries(Open))

# %%
stock_series = stocks[stock_symbol].get_series()
stock_series
# Out:
# array([ 68.93000031,  69.25      ,  68.73000336, ..., 158.25999451,
#        158.52999878, 159.25999451])

# %%
stock_df = stocks[stock_symbol].get_as_df()
stock_df
# Out:
#                   Open
# Date
# 2013-01-02   68.930000
# 2013-01-03   69.250000
# 2013-01-04   68.730003
# 2013-01-07   68.830002
# 2013-01-08   68.279999
# ...                ...
# 2023-10-09  155.080002
# 2023-10-10  156.229996
# 2023-10-11  158.259995
# 2023-10-12  158.529999
# 2023-10-13  159.259995
#
# [2715 rows x 1 columns]

# %% [markdown]
# ### Plot Raw Data

# %%
stocks[stock_symbol].plot(tick_skip=350)

# %% [markdown]
# ### Get Descriptive Statistics of Raw Data

# %%
stocks[stock_symbol].get_statistics()
# Out:
#               Open
# count  2715.000000
# mean    102.222597
# std      30.650945
# min      56.389999
# 25%      75.395000
# 50%      92.050003
# 75%     134.105003
# max     165.210007

# %%
stocks[stock_symbol].max_min_range()
# Out:
# {'Max': Open    165.210007
#  dtype: float64,
#  'Min': Open    56.389999
#  dtype: float64,
#  'Range': Open    108.820007
#  dtype: float64}

# %% [markdown]
# ### Check Stationarity of Raw Data
#
# - With financial data, we expect it to be non-stationary.
#     - Can we verify this non-stationary with plotting the Autocorrelation?

# %%
stocks[stock_symbol].stationarity_test(stock_df)
# Out:
# Series is non-stationary as 0.8459770610115512 > 0.05

# %% [markdown]
# ### Plot Autocorrelation and Partial Autocorrelation of Raw Data
#
# - Below, there seems to be a high ACor, which means there's NOT such a difference between our 1st observation and k-th lag observation
#     - What to do with this?  We must take the `returns`.
# - The Partial ACor dies out after 2. Why?

# %%
stocks[stock_symbol].plot_autocorrelation(35)

# %%
stocks[stock_symbol].plot_partial_autocorrelation(35)

# %% [markdown]
# ### Get Returns Data
#
# - Forecast returns
# - Why: To have more stationarity (for the returns) compared to the prices `Open`/`Close` which is non-stationary
# - Calculate with the `change` between $ z_t $ and $ z_{t-1} $
# $$ Change = ((z_t - z_{t-1}) \div | z_{t-1} |) \space \rightarrow decimal \space form $$
# $$ Percent \space Change = Change \times 100 \space \rightarrow pecent \space form $$
#     - If `change` < 0, then stock price is going down, hence a **loss** from $ z_{t-1} \rightarrow z_t $
#     - If `change` > 0, then stock price is going up, hence a **gain** from $ z_{t-1} \rightarrow z_t $
#     - If `change` = 0, then stock price is constant, hence a **no loss nor no gain** from $ z_{t-1} \rightarrow z_t $
# - NOTE: Shift the date by 1 because we don't have anything to subtract the 0th date by.

# %%
stock_returns = stocks[stock_symbol].data_augment_for_returns()
stock_returns
# Out:
# UnivariateTimeSeries(Returns)

# %%
stock_returns_df = stock_returns.get_as_df()
stock_returns_df
# Out:
#              Returns
# Date
# 2013-01-03  0.004642
# 2013-01-04 -0.007509
# 2013-01-07  0.001455
# 2013-01-08 -0.007991
# 2013-01-09  0.005565
# ...              ...
# 2023-10-09 -0.022502
# 2023-10-10  0.007415
# 2023-10-11  0.012994
# 2023-10-12  0.001706
# 2023-10-13  0.004605
#
# [2714 rows x 1 columns]

# %% [markdown]
# ### Plot Returns Data

# %%
stock_returns.plot(tick_skip=150)

# %% [markdown]
# ### Get Descriptive Statistics of Returns Data

# %%
stock_returns.get_statistics()
# Out:
#            Returns
# count  2714.000000
# mean      0.000390
# std       0.012739
# min      -0.103738
# 25%      -0.005684
# 50%       0.000268
# 75%       0.006510
# max       0.109252

# %% [markdown]
# ### Check Stationarity of Returns Data
# - adfuller. See documentation

# %%
stock_returns.stationarity_test(stock_returns_df)
# Out:
# Series is stationary as 0.0 < 0.05

# %% [markdown]
# ### Plot Autocorrelation and Partial Autocorrelation of Returns Data
#
# - Below, the ACor between our 1st observation and k-th lag observation is low. This ACor resembles the Raw Data Partial ACor plot. Why?
# - The Partial ACor is similar (to the Raw Data Partial ACor plo), except it here, it dies out at 2 (compared to the Raw Data Partial ACor plot which dies out after 2). Why?

# %%
stock_returns.plot_autocorrelation(35)

# %%
stock_returns.plot_partial_autocorrelation(35)

# %% [markdown]
# ### Split Returns Data
#
# - Splitting so we can forecast the last 7 days. Do this type of forecast to see how model is performing. If model performs how we need, then update notebook to forecast the next 7 days.

# %%
stock_returns_len = len(stock_returns_df)
stock_returns_len
# Out:
# 2714

# %%
get_train_len = len(stock_returns_df[:2700])
get_train_len
# Out:
# 2700

# %%
get_train_percentage = float(get_train_len / stock_returns_len)
get_train_percentage
# Out:
# 0.9948415622697127

# %%
train, validation, test = stock_returns.get_train_validation_test_split(get_train_percentage, 0.0)
# Out:
# 0 2700
# 2700 2700
# 2700 2714

# %%
train
# Out:
# UnivariateTimeSeries(UnivariateTimeSeries(Returns)[0:2700])

# %%
train.get_as_df()
# Out:
#             UnivariateTimeSeries(Returns)[0:2700]
# Date
# 2013-01-03                               0.004642
# 2013-01-04                              -0.007509
# 2013-01-07                               0.001455
# 2013-01-08                              -0.007991
# 2013-01-09                               0.005565
# ...                                           ...
# 2023-09-19                              -0.007894
# 2023-09-20                               0.001347
# 2023-09-21                               0.004034
# 2023-09-22                              -0.012358
# 2023-09-25                               0.000863
#
# [2700 rows x 1 columns]

# %%
validation
# Out:
# UnivariateTimeSeries(UnivariateTimeSeries(Returns)[2700:2700])

# %%
validation.get_as_df()
# Out:
# Empty DataFrame
# Columns: [UnivariateTimeSeries(Returns)[2700:2700]]
# Index: []

# %%
test
# Out:
# UnivariateTimeSeries(UnivariateTimeSeries(Returns)[2700:2714])

# %%
test.get_as_df()
# Out:
#             UnivariateTimeSeries(Returns)[2700:2714]
# Date
# 2023-09-26                                  0.003511
# 2023-09-27                                 -0.005769
# 2023-09-28                                  0.000000
# 2023-09-29                                  0.006358
# 2023-10-02                                 -0.021714
# 2023-10-03                                  0.001254
# 2023-10-04                                 -0.000251
# 2023-10-05                                  0.005011
# 2023-10-06                                 -0.011218
# 2023-10-09                                 -0.022502
# 2023-10-10                                  0.007415
# 2023-10-11                                  0.012994
# 2023-10-12                                  0.001706
# 2023-10-13                                  0.004605

# %%
expected_forecast = test.get_series()
expected_forecast
# Out:
# array([ 0.00351055, -0.00576901,  0.        ,  0.00635802, -0.02171375,
#         0.00125398, -0.00025054,  0.00501098, -0.01121847, -0.02250231,
#         0.00741549,  0.01299366,  0.00170608,  0.00460478])

# %% [markdown]
# ### Initialize Autoregressive AR(p) Model
#
# - How to determine the proper lag value? Look at the Partial ACor plot for the `Returns`. Being that we're out of the blue area at lag 2, we'll set our lag to be 2. We'll also try other lag values where the lag is further outside the blue.
#     - Why Partial ACor plot and not ACor plot?
# - How to understand the model summary?

# %%
positive_pacor = [6, 10, 17]
negative_pacor = [2, 5, 16, 22, 31]
lags_to_test = positive_pacor + negative_pacor
lags_to_test = sorted(lags_to_test)
lags_to_test
# Out:
# [2, 5, 6, 10, 16, 17, 22, 31]

# %%
# create an object from the AR() class
ar_model_class = AR()

# call the function to train our AR model
trained_ar_models = ar_model_class.train_ar_model(train.get_series(), lags_to_test)
# Out:
# Model 1 with a lag of 2
# Model 2 with a lag of 5
# Model 3 with a lag of 6
# Model 4 with a lag of 10
# Model 5 with a lag of 16
# Model 6 with a lag of 17
# Model 7 with a lag of 22
# Model 8 with a lag of 31

# %%
len_historical_data, historical_data = train.get_historical_data()
len_historical_data
# Out:
# 2700

# %% [markdown]
# ### Predict Forecasts of Retruns Data

# %%
predictions = ar_model_class.predict(trained_ar_models, len_historical_data, train, test)
predictions
# Out:
# Model 1 <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x19e73c280>
# Model 2 <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x19e6aef70>
# Model 3 <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x19e690160>
# Model 4 <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x19e690e20>
# Model 5 <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x19e624460>
# Model 6 <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x19e5b15e0>
# Model 7 <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x19e49fe80>
# Model 8 <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x19e48a2b0>
# [array([0.00070358, 0.0003801 , 0.00039308, 0.00040074, 0.00040021,
#         0.00040003, 0.00040005, 0.00040005, 0.00040005, 0.00040005,
#         0.00040005, 0.00040005, 0.00040005, 0.00040005]),
#  array([0.00100927, 0.00049244, 0.00063773, 0.00095802, 0.00033323,
#         0.00035104, 0.0003795 , 0.00037465, 0.00038001, 0.00040792,
#         0.00040522, 0.00040326, 0.0004028 , 0.00040172]),
#  array([0.00093195, 0.0003383 , 0.00065848, 0.0010243 , 0.00010095,
#         0.00037392, 0.00040027, 0.00037469, 0.00038882, 0.00042871,
#         0.00039707, 0.00040135, 0.00040237, 0.00040046]),
#  array([ 0.00101362,  0.00049951,  0.00095315,  0.00112736, -0.00022456,
#          0.00031631,  0.00065609,  0.00039261, -0.00010377,  0.00046124,
#          0.00039185,  0.00040919,  0.00046112,  0.00043828]),
#  array([ 1.35449341e-03,  9.42903473e-04,  8.21859548e-04,  5.23203917e-04,
#         -6.21429497e-04,  5.41727404e-05,  3.73935386e-04,  2.27998241e-04,
#         -7.93482063e-05,  5.95224080e-04,  7.19844933e-04,  3.99452758e-04,
#          6.27379952e-04,  6.72875393e-04]),
#  array([ 1.49132601e-03,  1.24197984e-03,  6.41662960e-04,  2.82590742e-04,
#         -3.32655045e-04,  3.05919482e-04,  4.52265759e-04,  2.94741340e-04,
#         -5.19645155e-05,  5.77413834e-04,  7.34685000e-04,  2.95644899e-04,
#          3.78613452e-04,  7.03280808e-04]),
#  array([ 1.34739625e-03,  1.47895774e-03,  5.43903817e-04,  1.04365734e-04,
#         -5.16860136e-04,  5.05889790e-06,  1.52676987e-04,  6.95772324e-04,
#          2.26303307e-04,  2.58851707e-04,  4.79211080e-04,  2.25413176e-04,
#          3.02901680e-04,  6.63683819e-04]),
#  array([ 1.55775600e-03,  1.80089763e-03,  1.09503926e-03, -4.19952792e-04,
#          7.57248436e-04,  1.29101531e-03, -3.66758830e-04,  1.10890131e-03,
#         -1.18945516e-04, -5.91259075e-06,  5.07704078e-04, -4.07796297e-05,
#          1.14859995e-04,  1.78721865e-04])]

# %%
mse_gsts = EvaluationMetric.eval_mse(expected_forecast, predictions)
mse_gsts
# Out:
# expected [ 0.00351055 -0.00576901  0.          0.00635802 -0.02171375  0.00125398
#  -0.00025054  0.00501098 -0.01121847 -0.02250231  0.00741549  0.01299366
#   0.00170608  0.00460478] predicted [0.00070358 0.0003801  0.00039308 0.00040074 0.00040021 0.00040003
#  0.00040005 0.00040005 0.00040005 0.00040005 0.00040005 0.00040005
#  0.00040005 0.00040005] mse 0.010279951446307022
# expected [ 0.00351055 -0.00576901  0.          0.00635802 -0.02171375  0.00125398
#  -0.00025054  0.00501098 -0.01121847 -0.02250231  0.00741549  0.01299366
#   0.00170608  0.00460478] predicted [0.00100927 0.00049244 0.00063773 0.00095802 0.00033323 0.00035104
#  0.0003795  0.00037465 0.00038001 0.00040792 0.00040522 0.00040326
#  0.0004028  0.00040172] mse 0.010247772746313555
# expected [ 0.00351055 -0.00576901  0.          0.00635802 -0.02171375  0.00125398
#  -0.00025054  0.00501098 -0.01121847 -0.02250231  0.00741549  0.01299366
#   0.00170608  0.00460478] predicted [0.00093195 0.0003383  0.00065848 0.0010243  0.00010095 0.00037392
#  0.00040027 0.00037469 0.00038882 0.00042871 0.00039707 0.00040135
#  0.00040237 0.00040046] mse 0.010209121331345663
# expected [ 0.00351055 -0.00576901  0.          0.00635802 -0.02171375  0.00125398
#  -0.00025054  0.00501098 -0.01121847 -0.02250231  0.00741549  0.01299366
#   0.00170608  0.00460478] predicted [ 0.00101362  0.00049951  0.00095315  0.00112736 -0.00022456  0.00031631
#   0.00065609  0.00039261 -0.00010377  0.00046124  0.00039185  0.00040919
#   0.00046112  0.00043828] mse 0.010128053415641138
# expected [ 0.00351055 -0.00576901  0.          0.00635802 -0.02171375  0.00125398
#  -0.00025054  0.00501098 -0.01121847 -0.02250231  0.00741549  0.01299366
#   0.00170608  0.00460478] predicted [ 1.35449341e-03  9.42903473e-04  8.21859548e-04  5.23203917e-04
#  -6.21429497e-04  5.41727404e-05  3.73935386e-04  2.27998241e-04
#  -7.93482063e-05  5.95224080e-04  7.19844933e-04  3.99452758e-04
#   6.27379952e-04  6.72875393e-04] mse 0.010112427752516499
# expected [ 0.00351055 -0.00576901  0.          0.00635802 -0.02171375  0.00125398
#  -0.00025054  0.00501098 -0.01121847 -0.02250231  0.00741549  0.01299366
#   0.00170608  0.00460478] predicted [ 1.49132601e-03  1.24197984e-03  6.41662960e-04  2.82590742e-04
#  -3.32655045e-04  3.05919482e-04  4.52265759e-04  2.94741340e-04
#  -5.19645155e-05  5.77413834e-04  7.34685000e-04  2.95644899e-04
#   3.78613452e-04  7.03280808e-04] mse 0.010182484728577969
# expected [ 0.00351055 -0.00576901  0.          0.00635802 -0.02171375  0.00125398
#  -0.00025054  0.00501098 -0.01121847 -0.02250231  0.00741549  0.01299366
#   0.00170608  0.00460478] predicted [ 1.34739625e-03  1.47895774e-03  5.43903817e-04  1.04365734e-04
#  -5.16860136e-04  5.05889790e-06  1.52676987e-04  6.95772324e-04
#   2.26303307e-04  2.58851707e-04  4.79211080e-04  2.25413176e-04
#   3.02901680e-04  6.63683819e-04] mse 0.01015579538138965
# expected [ 0.00351055 -0.00576901  0.          0.00635802 -0.02171375  0.00125398
#  -0.00025054  0.00501098 -0.01121847 -0.02250231  0.00741549  0.01299366
#   0.00170608  0.00460478] predicted [ 1.55775600e-03  1.80089763e-03  1.09503926e-03 -4.19952792e-04
#   7.57248436e-04  1.29101531e-03 -3.66758830e-04  1.10890131e-03
#  -1.18945516e-04 -5.91259075e-06  5.07704078e-04 -4.07796297e-05
#   1.14859995e-04  1.78721865e-04] mse 0.01034224127961506

# %% [markdown]
# ### Plot Actual Forecasts vs Predicted Forecasts for Returns Data

# %%
EvaluationMetric.plot_forecast(expected_forecast, predictions, lags_to_test)

# %% [markdown]
# ### Initialize Persistence Random Walk Model

# %%
# create an object from the PersistenceWalkForward() class
random_walk_model = PersistenceWalkForward()

# %%
stock_returns_df
# Out:
#              Returns
# Date
# 2013-01-03  0.004642
# 2013-01-04 -0.007509
# 2013-01-07  0.001455
# 2013-01-08 -0.007991
# 2013-01-09  0.005565
# ...              ...
# 2023-10-09 -0.022502
# 2023-10-10  0.007415
# 2023-10-11  0.012994
# 2023-10-12  0.001706
# 2023-10-13  0.004605
#
# [2714 rows x 1 columns]

# %%
stock_returns.get_series()
# Out:
# array([ 0.00464239, -0.00750898,  0.00145495, ...,  0.01299366,
#         0.00170608,  0.00460478])

# %%
stock_returns_lags_df = random_walk_model.augment_data(stock_returns_df, 1)
stock_returns_lags_df
# Out:
#                t - 1     t + 1
# Date
# 2013-01-03       NaN  0.004642
# 2013-01-04  0.004642 -0.007509
# 2013-01-07 -0.007509  0.001455
# 2013-01-08  0.001455 -0.007991
# 2013-01-09 -0.007991  0.005565
# ...              ...       ...
# 2023-10-09 -0.011218 -0.022502
# 2023-10-10 -0.022502  0.007415
# 2023-10-11  0.007415  0.012994
# 2023-10-12  0.012994  0.001706
# 2023-10-13  0.001706  0.004605
#
# [2714 rows x 2 columns]

# %%
X = stock_returns_lags_df.values
train, test = X[1:len(X)-7], X[len(X)-7:]
train_X, train_y = train[:,0], train[:,1]
test_X, test_y = test[:,0], test[:,1]

# %%
import numpy as np

# %%
prw_predictions = random_walk_model.predict(test_X)
prw_predictions = np.array(prw_predictions)
prw_predictions
# Out:
# Predicted Forecasts: [-0.00025053882090431134]
# Predicted Forecasts: [-0.00025053882090431134, 0.005010980785107533]
# Predicted Forecasts: [-0.00025053882090431134, 0.005010980785107533, -0.011218467348045214]
# Predicted Forecasts: [-0.00025053882090431134, 0.005010980785107533, -0.011218467348045214, -0.02250231454631524]
# Predicted Forecasts: [-0.00025053882090431134, 0.005010980785107533, -0.011218467348045214, -0.02250231454631524, 0.007415488024930417]
# Predicted Forecasts: [-0.00025053882090431134, 0.005010980785107533, -0.011218467348045214, -0.02250231454631524, 0.007415488024930417, 0.01299365573072886]
# Predicted Forecasts: [-0.00025053882090431134, 0.005010980785107533, -0.011218467348045214, -0.02250231454631524, 0.007415488024930417, 0.01299365573072886, 0.0017060803856483453]
# array([-0.00025054,  0.00501098, -0.01121847, -0.02250231,  0.00741549,
#         0.01299366,  0.00170608])

# %%
mse_stock_returns = EvaluationMetric.eval_mse(test_y, prw_predictions, per_element=False)
mse_stock_returns
# Out:
# Test MSE: 0.000

# %%
lags_to_test = [0]
EvaluationMetric.plot_forecast(test_y, prw_predictions, lags_to_test, with_lags=False)

# %% [markdown]
# ### ARCH

# %%
from arch import arch_model

# %%
am = arch_model(aapl_returns.get_series())
am
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 am = arch_model(aapl_returns.get_series())
#       2 am
#
# NameError: name 'aapl_returns' is not defined

# %%
res = am.fit()

# %%
print(res.summary())

# %%
res.plot(annualize="D")

# %% [markdown]
# ### Follow-up
# - What can we determine from this?
#     - None of the models with the specified lag are performing well. Why?
# - Which AR(p) lag performs the best?
#     - Difficult to state.
# - Can we do better?
#     - We must lol!
