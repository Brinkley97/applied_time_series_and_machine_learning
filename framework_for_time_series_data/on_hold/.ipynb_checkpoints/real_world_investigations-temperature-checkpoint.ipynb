# %% [markdown]
# # Reproducing: Daily Minimum Temperate Data
# - NOTES: [real_world_investigations-base.ipynb](https://github.com/Brinkley97/applied_time_series_and_machine_learning/blob/main/framework_for_time_series_data/real_world_investigations-base.ipynb) by Detravious
#
# - TUTORIAL: [Autoregression Models for Time Series Forecasting With Python](https://machinelearningmastery.com/autoregression-models-time-series-forecasting-python/) by Jason Brownlee

# %%
import os
import sys
# Get the current working directory of the notebook
notebook_dir = os.getcwd()

# Add the parent directory to the system path
sys.path.append(os.path.join(notebook_dir, '../tslearn/'))

import matplotlib.pyplot as plt

from collections import namedtuple
from data_loader import build_air_temperature_uts
from ts_models import Model, AR, PersistenceWalkForward, MA, EvaluationMetric
from time_series import TimeSeriesFactory, TimeSeriesMixin, UnivariateTimeSeries

# %% [markdown]
# ## Daily Minimum Temperate Data Pipeline
#
# 1. Load Raw Data
# 2. Plot Raw Data
# 3. Get Descriptive Statistics (ie: mean, median, range, etc)
# 4. Check Stationarity of Raw Data
# 5. Plot Autocorrelation and Partial Autocorrelation
# 6. Split Data
# 7. Initialize Autoregressive AR(p) Model
# 8. Predict Forecasts
# 9. Plot Actual Forecasts vs Predicted Forecasts
# 10. Initialize Persistence Random Walk Model
# 11. Predict Forecasts on Raw Data for Persistence Random Walk Model
# 12. Follow-up

# %% [markdown]
# ### Load Raw Data

# %%
temperatures = build_air_temperature_uts()
temperatures
# Out:
# UnivariateTimeSeries(Temp)

# %% [markdown]
# - `class`: UnivariateTimeSeries
# - `object`: temperatures
# - `.method()`: get_as_df() and see more below

# %%
temp_df = temperatures.get_as_df()
temp_df
# Out:
#             Temp
# Date
# 1981-01-01  20.7
# 1981-01-02  17.9
# 1981-01-03  18.8
# 1981-01-04  14.6
# 1981-01-05  15.8
# ...          ...
# 1990-12-27  14.0
# 1990-12-28  13.6
# 1990-12-29  13.5
# 1990-12-30  15.7
# 1990-12-31  13.0
#
# [3650 rows x 1 columns]

# %% [markdown]
# ### Plot Raw Data

# %%
temperatures.plot(tick_skip=250)

# %% [markdown]
# ### Get Descriptive Statistics

# %%
temperatures.get_statistics()
# Out:
#               Temp
# count  3650.000000
# mean     11.177753
# std       4.071837
# min       0.000000
# 25%       8.300000
# 50%      11.000000
# 75%      14.000000
# max      26.300000

# %%
temperatures.range_skewness_kurtosis()
# Out:
# {'Range': Temp    26.3
#  dtype: float64,
#  'Skewness': Temp    0.172283
#  dtype: float64,
#  'Kurtosis': Temp   -0.063105
#  dtype: float64}

# %% [markdown]
# ### Check Stationarity of Raw Data

# %%
temperatures.stationarity_test(temp_df)
# Out:
# ADF Statistic: -4.444805
# p-value: 0.000247 < 0.05 , so reject null-hypothesis as the TS is stationary
# Critical Values:
# 	1%: -3.432
# 	5%: -2.862
# 	10%: -2.567

# %% [markdown]
# ### Plot Autocorrelation and Partial Autocorrelation
# - How the relationship between observations and its historical data changes over time.
# - In this case, we have a positive high autocorrelation meaning that we have some relationships between the 1st observation and the k-th observation (at that lag).
# - Look for which points fall outside of blue region.

# %%
temperatures.plot_autocorrelation(35)

# %%
temperatures.plot_partial_autocorrelation(35)

# %% [markdown]
# ### Split Data
# - Splitting according to the TUTORIAL so we can forecast the last 7 days. Do this type of forecast to see how model is performing. If model performs how we need, then update notebook to forecast the next 7 days.

# %%
# train_2, test_2 = temperatures.get_series()[1:len(temperatures.get_series())-7], temperatures.get_series()[len(temperatures.get_series())-7:]

# %%
from pandas import read_csv
from matplotlib import pyplot
from statsmodels.tsa.ar_model import AutoReg
from sklearn.metrics import mean_squared_error
from math import sqrt
# load dataset
series = read_csv('../../datasets/daily-min-temperatures.csv', header=0, index_col=0, parse_dates=True)

# %%
# split dataset
X = series.values

# %%
# X

# %%
train, test = X[1:len(X)-7], X[len(X)-7:]
train
# Out:
# array([[17.9],
#        [18.8],
#        [14.6],
#        ...,
#        [13.2],
#        [13.9],
#        [10. ]])

# %%
test
# Out:
# array([[12.9],
#        [14.6],
#        [14. ],
#        [13.6],
#        [13.5],
#        [15.7],
#        [13. ]])

# %%
# # train autoregression
# model = AutoReg(train, lags=29)
# model_fit = model.fit()
# print('Coefficients: %s' % model_fit.params)
# # make predictions
# predictions = model_fit.predict(start=len(train), end=len(train)+len(test)-1, dynamic=False)
# for i in range(len(predictions)):
#  print('predicted=%f, expected=%f' % (predictions[i], test[i]))
# rmse = sqrt(mean_squared_error(test, predictions))
# print('Test RMSE: %.3f' % rmse)
# # plot results
# pyplot.plot(test)
# pyplot.plot(predictions, color='red')
# pyplot.show()

# %%
forecasting_step = 7
N = len(temperatures.get_series())
train = N - forecasting_step

# %%
X_train, y_test = temperatures.get_slice(1, train, True)
# Out:
# 1 3643

# %%
X_train.get_as_df().head(3)
# Out:
#             UnivariateTimeSeries(Temp)[1:3643]
# Date
# 1981-01-02                                17.9
# 1981-01-03                                18.8
# 1981-01-04                                14.6

# %%
y_test.get_as_df().tail(3)
# Out:
#             UnivariateTimeSeries(Temp)[1:3643]
# Date
# 1990-12-29                                13.5
# 1990-12-30                                15.7
# 1990-12-31                                13.0

# %% [markdown]
# ### Initialize AR Model
# - How to determine the proper lag value? Look at the Partial ACor plot. Being that we're out of the blue area at lag 3, we'll set our lag to be 3. We'll also test for lag 31 which is the first negative lag that's outside of the blue. The TUTORIAL has lag 29, so we'll test that as well.
# - How to understand the model summary?

# %%
lags_to_test = [3, 31, 29, 10]

# %%
ar_model_class = AR()

trained_ar_models = ar_model_class.train_ar_model(X_train.get_series(), lags_to_test)

# %%
# trained_ar_models[0]

# %%
# trained_ar_models[1]

# %%
# historical_data = X_train.get_historical_data(forecasting_step)
# historical_data

# %%
# len_historical_data

# %%
# historical_data

# %%
# Need to update AR predict class

# %% [markdown]
# ### Predict Forecasts on Raw Data for AR Model

# %%
predictions = ar_model_class.predict(trained_ar_models, X_train, lags_to_test)
predictions
# Out:
# [array([12.52383366, 12.51195846, 12.03705056, 13.11194386])]

# %%
y_test.get_series()
# Out:
# array([12.9, 14.6, 14. , 13.6, 13.5, 15.7, 13. ])

# %%
mse_temperatures = EvaluationMetric.eval_mse(y_test.get_series(), predictions[0], per_element=True)
mse_temperatures
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 mse_temperatures = EvaluationMetric.eval_mse(y_test.get_series(), predictions[0], per_element=True)
#       2 mse_temperatures
#
# File ~/Documents/development/applied_time_series_and_machine_learning/framework_for_time_series_data/on_hold/../tslearn/ts_models.py:424, in EvaluationMetric.eval_mse(true_labels, predictions, per_element)
#     422     for predictions_idx in range(len(predictions)):
#     423         prediction = predictions[predictions_idx]
# --> 424         mse = mean_squared_error(true_labels, prediction)
#     425         print('Test MSE: %.3f' % mse)
#     426 else:
#
# File ~/opt/anaconda3/envs/time_series/lib/python3.9/site-packages/sklearn/metrics/_regression.py:442, in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     382 def mean_squared_error(
#     383     y_true, y_pred, *, sample_weight=None, multioutput="uniform_average", squared=True
#     384 ):
#     385     """Mean squared error regression loss.
#     386
#     387     Read more in the :ref:`User Guide <mean_squared_error>`.
#    (...)
#     440     0.825...
#     441     """
# --> 442     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     443         y_true, y_pred, multioutput
#     444     )
#     445     check_consistent_length(y_true, y_pred, sample_weight)
#     446     output_errors = np.average((y_true - y_pred) ** 2, axis=0, weights=sample_weight)
#
# File ~/opt/anaconda3/envs/time_series/lib/python3.9/site-packages/sklearn/metrics/_regression.py:100, in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      66 def _check_reg_targets(y_true, y_pred, multioutput, dtype="numeric"):
#      67     """Check that y_true and y_pred belong to the same regression task.
#      68
#      69     Parameters
#    (...)
#      98         correct keyword.
#      99     """
# --> 100     check_consistent_length(y_true, y_pred)
#     101     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#     102     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#
# File ~/opt/anaconda3/envs/time_series/lib/python3.9/site-packages/sklearn/utils/validation.py:394, in check_consistent_length(*arrays)
#     383 def check_consistent_length(*arrays):
#     384     """Check that all arrays have consistent first dimensions.
#     385
#     386     Checks whether all objects in arrays have the same shape or length.
#    (...)
#     391         Objects that will be checked for consistent length.
#     392     """
# --> 394     lengths = [_num_samples(X) for X in arrays if X is not None]
#     395     uniques = np.unique(lengths)
#     396     if len(uniques) > 1:
#
# File ~/opt/anaconda3/envs/time_series/lib/python3.9/site-packages/sklearn/utils/validation.py:394, in <listcomp>(.0)
#     383 def check_consistent_length(*arrays):
#     384     """Check that all arrays have consistent first dimensions.
#     385
#     386     Checks whether all objects in arrays have the same shape or length.
#    (...)
#     391         Objects that will be checked for consistent length.
#     392     """
# --> 394     lengths = [_num_samples(X) for X in arrays if X is not None]
#     395     uniques = np.unique(lengths)
#     396     if len(uniques) > 1:
#
# File ~/opt/anaconda3/envs/time_series/lib/python3.9/site-packages/sklearn/utils/validation.py:335, in _num_samples(x)
#     333 if hasattr(x, "shape") and x.shape is not None:
#     334     if len(x.shape) == 0:
# --> 335         raise TypeError(
#     336             "Singleton array %r cannot be considered a valid collection." % x
#     337         )
#     338     # Check that shape is returning an integer or default to len
#     339     # Dask dataframes may not return numeric shape[0] value
#     340     if isinstance(x.shape[0], numbers.Integral):
#
# TypeError: Singleton array 10.261850677727221 cannot be considered a valid collection.

# %% [markdown]
# ### Plot Actual Forecasts vs Predicted Forecasts

# %%
EvaluationMetric.plot_forecast(expected_forecast, predictions, lags_to_test, with_lags=True)

# %% [markdown]
# ### Initialize Persistence Random Walk Model

# %%
temp_df

# %%
temp_values = temperatures.get_series()
temp_values

# %%
temp_lags_df = pd.concat([temp_df.shift(1), temp_df], axis=1)
temp_lags_df

# %%
temp_lags_df.columns = ['t - 1', 't + 1']
temp_lags_df

# %%
X = temp_lags_df.values
train, test = X[1:len(X)-7], X[len(X)-7:]
train_X, train_y = train[:,0], train[:,1]
test_X, test_y = test[:,0], test[:,1]

# %%
len(train), len(test), len(train_X), len(train_y), len(test_X), len(test_y)

# %%
prw_model = PersistenceWalkForward()
prw_model

# %% [markdown]
# ### Predict Forecasts on Raw Data for Persistence Random Walk Model

# %%
prw_predictions = prw_model.predict(test_X)
prw_predictions = np.array(prw_predictions)
prw_predictions

# %%
test_y

# %%
mse_temperatures = EvaluationMetric.eval_mse(test_y, prw_predictions, per_element=False)
mse_temperatures

# %%
lags_to_test = [0]
EvaluationMetric.plot_forecast(test_y, prw_predictions, lags_to_test, with_lags=False)

# %% [markdown]
# ### Initialize MA(q) Model
#
# - How to determine the proper error term? Look at the ACor plot. There's no real indication of what values to choose, so I'll randomly pick some.
# - How to understand the model summary?

# %%
train, validation, test = temperatures.get_train_validation_test_split(0.9983, 0.0)

# %%
errors_to_test = [3, 8, 17, 31, 29]

# %%
ma_model_class = MA()

trained_ma_models = ma_model_class.train_model(train.get_series(), errors_to_test)

# %%
ma_predictions = ma_model_class.predict(trained_ma_models, len_historical_data, train, test)
ma_predictions

# %%
expected_forecast = test.get_series()
expected_forecast

# %%
mse_temperatures = EvaluationMetric.eval_mse(expected_forecast, ma_predictions, per_element=True)
mse_temperatures

# %%
EvaluationMetric.plot_forecast(expected_forecast, ma_predictions, errors_to_test, with_lags=True)

# %% [markdown]
# ### Follow-up
# - What can we determine from this?
# - Which AR(p) lag performs the best?
# - Can we do better?
