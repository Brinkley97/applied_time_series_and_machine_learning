# %% [markdown]
# # Creating a TS a Trend, Seasonality, and Irregularity

# %%
import numpy as np

import matplotlib.pyplot as plt

# %%
def generate_I(t):
    """
    """
    rng = np.random.default_rng()
    return rng.random()

# %%
def generate_ts_with_components(T: float, S: float, I: float, noise: float):
    """Generate a time series given the component.
    
    """
    ts = []
    ss = []
    irs = [] 
    ts_with_components = [] 
    
    for t in range(1, 51):
        trend = T * t
        ts.append(trend)
        
        seasonal = 1.6 * np.sin(t * np.pi / 6)
        ss.append(seasonal)
        
        rng = np.random.default_rng()
        update_i = rng.random()
        
        irregular = 0.7 * update_i + noise
        print(irregular)
        irs.append(irregular)
        
    return ts, ss, irs

# %% [markdown]
# ## Trend
#
# $$ T_t = 1 + 0.1t $$
#
# ## Seasonal
#
# $$ S_t = 1.6 sin([t * \pi] / 6) $$
#
# ## Irregular
#
# $$ I_t = 0.7 * I_{t - 1} + \epsilon_t $$

# %%
trend = 1 + 0.1

# %%
seasonal = 1.6

# %%
irregular_lag_k = 1
noise = 0.5

# %%
t, s, i = generate_ts_with_components(trend, seasonal, irregular_lag_k, noise)
# Out:
# 0.6060599462475185
# 1.1858624632593666
# 0.9334106858474822
# 0.5757635463305971
# 0.7242501641533029
# 0.560324388378941
# 0.7852567727309268
# 1.1298249205918323
# 0.7814435891004265
# 1.0076541800661787
# 0.5833528347878527
# 0.560713203453947
# 1.0043923821333625
# 0.8387329704671294
# 0.6104270434678435
# 0.764985371856961
# 0.511276079157638
# 0.6365164949402019
# 1.0747515497763236
# 0.7045186295066008
# 0.9498755769463101
# 1.0679937524114202
# 0.8341457453651814
# 0.8866470691163031
# 1.123858287746335
# 1.1262193179293987
# 0.9865545593038358
# 1.0530554565259562
# 1.1292269196347724
# 0.8042225721445395
# 1.134161010808007
# 0.6046845000913668
# 0.7863949168613982
# 0.5268264380259783
# 0.9015537407675667
# 0.8495120081852638
# 0.9137689968148359
# 0.908416495132776
# 0.7245119100576753
# 1.052544282197146
# 0.9284886102239058
# 0.9579506487403942
# 0.9141186060620112
# 1.1395377282254366
# 0.8299123192230992
# 0.8304732083745872
# 0.9057834421049622
# 1.1949253975209293
# 0.8996305591727429
# 0.6426563309302761

# %%
t
# Out:
# [1.1,
#  2.2,
#  3.3000000000000003,
#  4.4,
#  5.5,
#  6.6000000000000005,
#  7.700000000000001,
#  8.8,
#  9.9,
#  11.0,
#  12.100000000000001,
#  13.200000000000001,
#  14.3,
#  15.400000000000002,
#  16.5,
#  17.6,
#  18.700000000000003,
#  19.8,
#  20.900000000000002,
#  22.0,
#  23.1,
#  24.200000000000003,
#  25.3,
#  26.400000000000002,
#  27.500000000000004,
#  28.6,
#  29.700000000000003,
#  30.800000000000004,
#  31.900000000000002,
#  33.0,
#  34.1,
#  35.2,
#  36.300000000000004,
#  37.400000000000006,
#  38.5,
#  39.6,
#  40.7,
#  41.800000000000004,
#  42.900000000000006,
#  44.0,
#  45.1,
#  46.2,
#  47.300000000000004,
#  48.400000000000006,
#  49.50000000000001,
#  50.6,
#  51.7,
#  52.800000000000004,
#  53.900000000000006,
#  55.00000000000001]

# %%
s
# Out:
# [0.7999999999999999,
#  1.3856406460551018,
#  1.6,
#  1.3856406460551023,
#  0.7999999999999999,
#  1.9594348786357652e-16,
#  -0.7999999999999997,
#  -1.3856406460551014,
#  -1.6,
#  -1.3856406460551018,
#  -0.8000000000000007,
#  -3.9188697572715305e-16,
#  0.8,
#  1.3856406460551014,
#  1.6,
#  1.3856406460551027,
#  0.7999999999999997,
#  5.878304635907295e-16,
#  -0.7999999999999987,
#  -1.385640646055102,
#  -1.6,
#  -1.3856406460551027,
#  -0.8000000000000024,
#  -7.837739514543061e-16,
#  0.8000000000000012,
#  1.385640646055102,
#  1.6,
#  1.385640646055103,
#  0.8,
#  3.821888382358284e-15,
#  -0.7999999999999983,
#  -1.3856406460551005,
#  -1.6,
#  -1.3856406460551014,
#  -0.8000000000000003,
#  -1.175660927181459e-15,
#  0.799999999999998,
#  1.3856406460551005,
#  1.6,
#  1.3856406460551016,
#  0.8000000000000054,
#  1.3716044150450357e-15,
#  -0.799999999999998,
#  -1.3856406460551003,
#  -1.6,
#  -1.3856406460551045,
#  -0.8000000000000006,
#  -1.5675479029086122e-15,
#  0.7999999999999978,
#  1.3856406460551032]

# %%
i
# Out:
# [0.6060599462475185,
#  1.1858624632593666,
#  0.9334106858474822,
#  0.5757635463305971,
#  0.7242501641533029,
#  0.560324388378941,
#  0.7852567727309268,
#  1.1298249205918323,
#  0.7814435891004265,
#  1.0076541800661787,
#  0.5833528347878527,
#  0.560713203453947,
#  1.0043923821333625,
#  0.8387329704671294,
#  0.6104270434678435,
#  0.764985371856961,
#  0.511276079157638,
#  0.6365164949402019,
#  1.0747515497763236,
#  0.7045186295066008,
#  0.9498755769463101,
#  1.0679937524114202,
#  0.8341457453651814,
#  0.8866470691163031,
#  1.123858287746335,
#  1.1262193179293987,
#  0.9865545593038358,
#  1.0530554565259562,
#  1.1292269196347724,
#  0.8042225721445395,
#  1.134161010808007,
#  0.6046845000913668,
#  0.7863949168613982,
#  0.5268264380259783,
#  0.9015537407675667,
#  0.8495120081852638,
#  0.9137689968148359,
#  0.908416495132776,
#  0.7245119100576753,
#  1.052544282197146,
#  0.9284886102239058,
#  0.9579506487403942,
#  0.9141186060620112,
#  1.1395377282254366,
#  0.8299123192230992,
#  0.8304732083745872,
#  0.9057834421049622,
#  1.1949253975209293,
#  0.8996305591727429,
#  0.6426563309302761]

# %%
def plot_component(component: float):
    
    x = range(1, 51)
    y = component
    plt.plot(x, y)
    plt.show

# %%
plot_component(t)

# %%
plot_component(s)

# %%
plot_component(i)
